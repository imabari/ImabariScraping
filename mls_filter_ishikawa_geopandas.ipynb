# %% [markdown]
# <a href="https://colab.research.google.com/github/imabari/ImabariScraping/blob/master/mls_filter_ishikawa_geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pathlib
import re

# %%
import pandas as pd

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko"
}

# %%
def fetch_soup(url, parser="html.parser"):

    r = requests.get(url, headers=headers)
    r.raise_for_status()

    soup = BeautifulSoup(r.content, parser)

    return soup

# %%
def fetch_file(url, dir="."):

    p = pathlib.Path(dir, pathlib.PurePath(url).name)
    p.parent.mkdir(parents=True, exist_ok=True)

    r = requests.get(url)
    r.raise_for_status()

    with p.open(mode="wb") as fw:
        fw.write(r.content)
    return p

# %% [markdown]
# # スクレイピング

# %%
url = "https://location.services.mozilla.com/downloads"

soup = fetch_soup(url)

# %%
tag = soup.find("a", string=re.compile("^MLS-full-cell-export-\d{4}-\d{2}-\d{2}T000000.csv.gz"))

# %%
path_csv = fetch_file(tag.get("href"))

# %% [markdown]
# # 前処理

# %%
import pandas as pd

# %%
df0 = pd.read_csv(path_csv)

# %% [markdown]
# ## 抽出

# %% [markdown]
# MCC・MNC
#
# https://ja.wikipedia.org/wiki/Mobile_Network_Code

# %%
df1 = (
    df0[
        (df0["radio"] == "LTE")
        & (df0["mcc"].isin([440, 441]))
        & (df0["range"] > 0)
        & (df0["samples"] > 1)
    ]
    .dropna(subset=["unit"])
    .copy()
    .reset_index(drop=True)
)

# %%
df1["unit"] = df1["unit"].astype(int)

# %%
df1["created"] = pd.to_datetime(df1["created"], unit="s")
df1["updated"] = pd.to_datetime(df1["updated"], unit="s")

# %%
df1
# Out:
#        radio  mcc  net   area       cell  unit         lon        lat  range  \
# 0        LTE  440    0   4115    4629250   191  138.612602  35.621624   3572
# 1        LTE  440    0   4118    2102018    58  140.637758  35.900076   1469
# 2        LTE  440    0   4120    2305538    23  139.897278  36.555091    551
# 3        LTE  440    0   4120    2305793   153  139.606263  36.783805   1838
# 4        LTE  440    0   4120    2324481   327  139.977128  36.904738  24058
# ...      ...  ...  ...    ...        ...   ...         ...        ...    ...
# 419714   LTE  441    0  51970  236701226     0  130.426351  33.618492     54
# 419715   LTE  441    0  51970  236726628     0  130.438245  33.611217   1377
# 419716   LTE  441    0  51970  236736374     0  130.437587  33.611572     63
# 419717   LTE  441    0  51970  236808556     0  130.475078  33.593123     38
# 419718   LTE  441    0  51971  236753513     0  130.323299  33.563155    359
#
#         samples  changeable             created             updated  \
# 0            26           1 2021-03-05 23:42:54 2023-03-26 10:03:13
# 1            34           1 2018-04-19 11:50:25 2023-11-25 04:02:40
# 2            16           1 2018-11-29 12:13:05 2023-12-16 12:48:27
# 3            25           1 2022-07-30 15:17:02 2023-04-23 17:55:11
# 4           457           1 2019-04-12 16:08:59 2023-05-15 06:31:17
# ...         ...         ...                 ...                 ...
# 419714        3           1 2023-12-10 21:23:31 2023-12-10 21:23:31
# 419715       30           1 2023-11-05 17:22:57 2023-11-05 17:22:57
# 419716        3           1 2023-12-10 21:24:02 2023-12-10 21:24:02
# 419717        2           1 2023-11-03 22:51:52 2023-11-03 22:51:52
# 419718       16           1 2023-12-10 21:23:25 2023-12-10 21:23:25
#
#         averageSignal
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 419714            NaN
# 419715            NaN
# 419716            NaN
# 419717            NaN
# 419718            NaN
#
# [419719 rows x 14 columns]

# %%
df1["net"].value_counts().sort_index()
# Out:
# 0        868
# 2         68
# 4          3
# 5        339
# 10     97486
# 11    120310
# 20     77161
# 50     15250
# 51     81216
# 52      2976
# 53     20256
# 54      3786
# Name: net, dtype: int64

# %%
df1.shape
# Out:
# (419719, 14)

# %% [markdown]
# # geopandas

# %% [markdown]
# 国土数値情報　行政区域データ
#
# https://nlftp.mlit.go.jp/ksj/gml/datalist/KsjTmplt-N03-v3_1.html

# %%
# !wget https://nlftp.mlit.go.jp/ksj/gml/data/N03/N03-2023/N03-20230101_17_GML.zip
# Out:
# --2024-01-16 11:54:54--  https://nlftp.mlit.go.jp/ksj/gml/data/N03/N03-2023/N03-20230101_17_GML.zip
# Resolving nlftp.mlit.go.jp (nlftp.mlit.go.jp)... 147.154.1.1, 147.154.3.128, 130.35.228.165
# Connecting to nlftp.mlit.go.jp (nlftp.mlit.go.jp)|147.154.1.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5006858 (4.8M) [application/zip]
# Saving to: ‘N03-20230101_17_GML.zip’
#
# N03-20230101_17_GML 100%[===================>]   4.77M  5.89MB/s    in 0.8s
#
# 2024-01-16 11:54:56 (5.89 MB/s) - ‘N03-20230101_17_GML.zip’ saved [5006858/5006858]

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.23.5)

# %%
import geopandas as gpd

# %%
pt_df = gpd.GeoDataFrame(df1, geometry = gpd.points_from_xy(df1.lon, df1.lat), crs="EPSG:6668")
ishikawa = gpd.read_file("N03-20230101_17_GML.zip", encoding="cp932")

# %%
# 列名変更
ishikawa.rename(columns={"N03_001": "都道府県名", "N03_002": "支庁・振興局名", "N03_003": "郡・政令都市名", "N03_004": "市区町村名", "N03_007": "行政区域コード"}, inplace=True)

# %%
ishikawa
# Out:
#       OBJECTID 都道府県名 支庁・振興局名 郡・政令都市名 市区町村名 行政区域コード  Shape_Leng    Shape_Area  \
# 0          1.0   石川県    None    None   金沢市   17201    0.002292  1.089518e-07
# 1          2.0   石川県    None    None   金沢市   17201    0.002294  1.071961e-07
# 2          3.0   石川県    None    None   金沢市   17201    0.002589  1.224443e-07
# 3          4.0   石川県    None    None   金沢市   17201    0.002593  1.253285e-07
# 4          5.0   石川県    None    None   金沢市   17201    0.002594  1.239789e-07
# ...        ...   ...     ...     ...   ...     ...         ...           ...
# 1696    1697.0   石川県    None     鳳珠郡   能登町   17463    0.001279  7.981337e-08
# 1697    1698.0   石川県    None     鳳珠郡   能登町   17463    0.001787  1.533144e-07
# 1698    1699.0   石川県    None     鳳珠郡   能登町   17463    0.000357  7.984804e-09
# 1699    1700.0   石川県    None     鳳珠郡   能登町   17463    0.000799  2.411877e-08
# 1700    1701.0   石川県    None     鳳珠郡   能登町   17463    1.472149  2.777729e-02
#
#                                                geometry
# 0     POLYGON ((136.59501 36.61629, 136.59429 36.615...
# 1     POLYGON ((136.59537 36.61667, 136.59503 36.616...
# 2     POLYGON ((136.59647 36.61781, 136.59578 36.617...
# 3     POLYGON ((136.59688 36.61824, 136.59663 36.617...
# 4     POLYGON ((136.59769 36.61908, 136.59748 36.618...
# ...                                                 ...
# 1696  POLYGON ((137.24268 37.37134, 137.24267 37.371...
# 1697  POLYGON ((137.24184 37.37155, 137.24184 37.371...
# 1698  POLYGON ((137.24217 37.37152, 137.24211 37.371...
# 1699  POLYGON ((137.24396 37.37156, 137.24396 37.371...
# 1700  POLYGON ((137.12164 37.40049, 137.12179 37.400...
#
# [1701 rows x 9 columns]

# %%
# 石川県のみ抽出
spj = gpd.sjoin(pt_df, ishikawa).sort_values(by=["cell", "net", "行政区域コード", "samples"])
spj.shape
# Out:
# (3104, 24)

# %%
df2 = spj.drop_duplicates(subset=["cell", "行政区域コード"]).copy().reset_index(drop=True)

# %%
df2
# Out:
#      radio  mcc  net   area       cell  unit         lon        lat  range  \
# 0      LTE  440    0  16407    5128961   231  136.733376  36.744223  16355
# 1      LTE  440   20  16407    5128962   233  136.642738  36.617224    521
# 2      LTE  440   20  16407    5141506   409  136.654529  36.568320    202
# 3      LTE  440   20  16407    5141507   410  136.642740  36.570330   1104
# 4      LTE  440   53  49224   50338305   309  136.799322  37.008086    586
# ...    ...  ...  ...    ...        ...   ...         ...        ...    ...
# 2902   LTE  440   51  49220  267432460    24  136.460988  36.440223    709
# 2903   LTE  440   50  49217  267436032   438  136.656854  36.561694     24
# 2904   LTE  440   50  49217  267436033   438  136.656735  36.561668     25
# 2905   LTE  440   50  49218  267457025   151  136.759591  36.593192    316
# 2906   LTE  440   50  49218  267457026   151  136.757341  36.593773   1209
#
#       samples  ...                    geometry index_right OBJECTID  都道府県名  \
# 0          68  ...  POINT (136.73338 36.74422)        1059   1060.0    石川県
# 1           7  ...  POINT (136.64274 36.61722)           7      8.0    石川県
# 2          16  ...  POINT (136.65453 36.56832)           7      8.0    石川県
# 3          22  ...  POINT (136.64274 36.57033)           7      8.0    石川県
# 4          62  ...  POINT (136.79932 37.00809)        1562   1563.0    石川県
# ...       ...  ...                         ...         ...      ...    ...
# 2902       46  ...  POINT (136.46099 36.44022)        1062   1063.0    石川県
# 2903        2  ...  POINT (136.65685 36.56169)           7      8.0    石川県
# 2904        3  ...  POINT (136.65673 36.56167)           7      8.0    石川県
# 2905       26  ...  POINT (136.75959 36.59319)           7      8.0    石川県
# 2906       49  ...  POINT (136.75734 36.59377)           7      8.0    石川県
#
#      支庁・振興局名  郡・政令都市名  市区町村名 行政区域コード Shape_Leng Shape_Area
# 0       None     None   かほく市   17209   0.538833   0.006502
# 1       None     None    金沢市   17201   1.479955   0.047166
# 2       None     None    金沢市   17201   1.479955   0.047166
# 3       None     None    金沢市   17201   1.479955   0.047166
# 4       None      羽咋郡    志賀町   17384   1.833395   0.024993
# ...      ...      ...    ...     ...        ...        ...
# 2902    None     None    能美市   17211   0.641024   0.008456
# 2903    None     None    金沢市   17201   1.479955   0.047166
# 2904    None     None    金沢市   17201   1.479955   0.047166
# 2905    None     None    金沢市   17201   1.479955   0.047166
# 2906    None     None    金沢市   17201   1.479955   0.047166
#
# [2907 rows x 24 columns]

# %%
df_ishikawa = df2[df2["updated"] > "2024-01-01 16:11:00"].copy()

# %%
df_ishikawa
# Out:
#      radio  mcc  net   area       cell  unit         lon        lat  range  \
# 1      LTE  440   20  16407    5128962   233  136.642738  36.617224    521
# 2      LTE  440   20  16407    5141506   409  136.654529  36.568320    202
# 3      LTE  440   20  16407    5141507   410  136.642740  36.570330   1104
# 48     LTE  440   53  49287   50490881   105  136.284931  36.266432   4073
# 1057   LTE  440   20  16405   88096192   295  136.615676  36.498784    638
# ...    ...  ...  ...    ...        ...   ...         ...        ...    ...
# 2877   LTE  440   20  49157  177783143   234  136.628573  36.444329    698
# 2878   LTE  440   20  49157  177783145   142  136.627785  36.445504    992
# 2879   LTE  440   20  49157  177783148    96  136.619641  36.458359    183
# 2880   LTE  440   20  49159  177783652   256  136.648352  36.578797    265
# 2888   LTE  440   20  49159  177785901   450  136.621983  36.544004    214
#
#       samples  ...                    geometry index_right OBJECTID  都道府県名  \
# 1           7  ...  POINT (136.64274 36.61722)           7      8.0    石川県
# 2          16  ...  POINT (136.65453 36.56832)           7      8.0    石川県
# 3          22  ...  POINT (136.64274 36.57033)           7      8.0    石川県
# 48        157  ...  POINT (136.28493 36.26643)        1034   1035.0    石川県
# 1057       22  ...  POINT (136.61568 36.49878)           7      8.0    石川県
# ...       ...  ...                         ...         ...      ...    ...
# 2877       34  ...  POINT (136.62857 36.44433)        1061   1062.0    石川県
# 2878       25  ...  POINT (136.62779 36.44550)        1061   1062.0    石川県
# 2879        7  ...  POINT (136.61964 36.45836)        1061   1062.0    石川県
# 2880       19  ...  POINT (136.64835 36.57880)           7      8.0    石川県
# 2888        8  ...  POINT (136.62198 36.54400)        1063   1064.0    石川県
#
#      支庁・振興局名  郡・政令都市名  市区町村名 行政区域コード Shape_Leng Shape_Area
# 1       None     None    金沢市   17201   1.479955   0.047166
# 2       None     None    金沢市   17201   1.479955   0.047166
# 3       None     None    金沢市   17201   1.479955   0.047166
# 48      None     None    加賀市   17206   1.044371   0.030668
# 1057    None     None    金沢市   17201   1.479955   0.047166
# ...      ...      ...    ...     ...        ...        ...
# 2877    None     None    白山市   17210   2.116369   0.075719
# 2878    None     None    白山市   17210   2.116369   0.075719
# 2879    None     None    白山市   17210   2.116369   0.075719
# 2880    None     None    金沢市   17201   1.479955   0.047166
# 2888    None     None   野々市市   17212   0.266434   0.001364
#
# [401 rows x 24 columns]

# %%
# MCC MNC
pd.crosstab(df_ishikawa["net"], df_ishikawa["mcc"])
# Out:
# mcc  440
# net
# 11   165
# 20   235
# 53     1

# %%
df_ishikawa["市区町村名"].value_counts()
# Out:
# 金沢市     164
# 白山市      89
# 小松市      56
# 加賀市      39
# 野々市市     21
# 能美市      18
# 内灘町      12
# 川北町       2
# Name: 市区町村名, dtype: int64

# %%
df_ishikawa["career"] = "unknown"

# %%
df_ishikawa["career"].mask((df_ishikawa["mcc"] == 440) & (df_ishikawa["net"] == 11), "docomo", inplace=True)
df_ishikawa["career"].mask((df_ishikawa["mcc"] == 440) & (df_ishikawa["net"] == 20), "softbank", inplace=True)
df_ishikawa["career"].mask((df_ishikawa["mcc"] == 440) & (df_ishikawa["net"] == 53), "au", inplace=True)

# %%
df_ishikawa["color"] = df_ishikawa["career"].replace({"docomo": "red", "au": "orange", "softbank": "gray", "unknown": "black"})

# %%
df_ishikawa
# Out:
#      radio  mcc  net   area       cell  unit         lon        lat  range  \
# 1      LTE  440   20  16407    5128962   233  136.642738  36.617224    521
# 2      LTE  440   20  16407    5141506   409  136.654529  36.568320    202
# 3      LTE  440   20  16407    5141507   410  136.642740  36.570330   1104
# 48     LTE  440   53  49287   50490881   105  136.284931  36.266432   4073
# 1057   LTE  440   20  16405   88096192   295  136.615676  36.498784    638
# ...    ...  ...  ...    ...        ...   ...         ...        ...    ...
# 2877   LTE  440   20  49157  177783143   234  136.628573  36.444329    698
# 2878   LTE  440   20  49157  177783145   142  136.627785  36.445504    992
# 2879   LTE  440   20  49157  177783148    96  136.619641  36.458359    183
# 2880   LTE  440   20  49159  177783652   256  136.648352  36.578797    265
# 2888   LTE  440   20  49159  177785901   450  136.621983  36.544004    214
#
#       samples  ...  OBJECTID 都道府県名 支庁・振興局名  郡・政令都市名 市区町村名  行政区域コード  \
# 1           7  ...       8.0   石川県    None     None   金沢市    17201
# 2          16  ...       8.0   石川県    None     None   金沢市    17201
# 3          22  ...       8.0   石川県    None     None   金沢市    17201
# 48        157  ...    1035.0   石川県    None     None   加賀市    17206
# 1057       22  ...       8.0   石川県    None     None   金沢市    17201
# ...       ...  ...       ...   ...     ...      ...   ...      ...
# 2877       34  ...    1062.0   石川県    None     None   白山市    17210
# 2878       25  ...    1062.0   石川県    None     None   白山市    17210
# 2879        7  ...    1062.0   石川県    None     None   白山市    17210
# 2880       19  ...       8.0   石川県    None     None   金沢市    17201
# 2888        8  ...    1064.0   石川県    None     None  野々市市    17212
#
#       Shape_Leng Shape_Area    career   color
# 1       1.479955   0.047166  softbank    gray
# 2       1.479955   0.047166  softbank    gray
# 3       1.479955   0.047166  softbank    gray
# 48      1.044371   0.030668        au  orange
# 1057    1.479955   0.047166  softbank    gray
# ...          ...        ...       ...     ...
# 2877    2.116369   0.075719  softbank    gray
# 2878    2.116369   0.075719  softbank    gray
# 2879    2.116369   0.075719  softbank    gray
# 2880    1.479955   0.047166  softbank    gray
# 2888    0.266434   0.001364  softbank    gray
#
# [401 rows x 26 columns]

# %%
import folium
from folium import plugins

# %%
from folium.features import DivIcon
from folium.plugins import MarkerCluster

# %%
map = folium.Map(
    location=[36.5666, 136.6600],
    zoom_start=14,
    tiles="https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png",
    attr='&copy; <a href="https://maps.gsi.go.jp/development/ichiran.html">国土地理院</a>',
)

# %%
for i, r in df_ishikawa.iterrows():

    folium.Marker(
        location=[r.lat, r.lon],
        popup=folium.Popup(f'<p>{r.mcc} {r.net} {r.career}</p>', max_width=300),
        icon=folium.plugins.BeautifyIcon(icon_shape="circle-dot", border_width=5, border_color=r["color"])
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0553d09822b42f4fef13cf4a4ff3842 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0553d09822b42f4fef13cf4a4ff3842&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0553d09822b42f4fef13cf4a4ff3842 = L.map(
#                 &quot;map_e0553d09822b42f4fef13cf4a4ff3842&quot;,
#                 {
#                     center: [36.5666, 136.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f66e4bcf95c718ad70367235beeb270 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://maps.gsi.go.jp/development/ichiran.html\&quot;\u003e\u56fd\u571f\u5730\u7406\u9662\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0553d09822b42f4fef13cf4a4ff3842);
#
#
#             var marker_6d1f2ceffe92705d7ed35d0e1290b032 = L.marker(
#                 [36.6172237, 136.6427376],
#                 {}
#             ).addTo(map_e0553d09822b42f4fef13cf4a4ff3842);
#
#
#             var beautify_icon_fb07c1ddceb8143f11a848fe28ba7386 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;gray&quot;, &quot;borderWidth&quot;: 5, &quot;iconShape&quot;: &quot;circle-dot&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_6d1f2ceffe92705d7ed35d0e1290b032.setIcon(beautify_icon_fb07c1ddceb8143f11a848fe28ba7386);
#
#
#         var popup_cf1791bc8e06ddbfc0a430bab79122b2 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_5e89cbdce3ba276a4fb6f9680cffb6cc = $(`&lt;div id=&quot;html_5e89cbdce3ba276a4fb6f9680cffb6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p&gt;440 20 softbank&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_cf1791bc8e06ddbfc0a430bab79122b2.setContent(html_5e89cbdce3ba276a4fb6f9680cffb6cc);
#
#
#
#         marker_6d1f2ceffe92705d7ed35d0e1290b032.bindPopup(popup_cf1791bc8e06ddbfc0a430bab79122b2)
#         ;
#
#
#
#
#             var marker_402e40678358cbe8bef63ce20d7be814 = L.marker(
#                 [36.5683202, 136.654529],
#                 {}
#             ).addTo(map_e0553d09822b42f4fef13cf4a4ff3842);
#
#
#             var beautify_icon_09194fe78c2f9b0316d58e152aa5d529 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;gray&quot;, &quot;borderWidth&quot;: 5, &quot;iconShape&quot;: &quot;circle-dot&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_402e40678358cbe8bef63ce20d7be814.setIcon(beautify_icon_09194fe78c2f9b0316d58e152aa5d529);
#
#
#         var popup_0d7a57ae72f1d00feeb73e5c1e130b5c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_dee181c1dc1b0850a48f4d5d663ab5e4 = $(`&lt;div id=&quot;html_dee181c1dc1b0850a48f4d5d663ab5e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p&gt;440 20 softbank&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_0d7a57ae72f1d00feeb73e5c1e130b5c.setContent(html_dee181c1dc1b0850a48f4d5d663ab5e4);
#
#
#
#         marker_402e40678358cbe8bef63ce20d7be814.bindPopup(popup_0d7a57ae72f1d00feeb73e5c1e130b5c)
#         ;
#
#
#
#
#             var marker_2fec424927c86120f66179d179d54ed0 = L.marker(
#                 [36.5703303, 136.6427395],
#                 {}
#             ).addTo(map_e0553d09822b42f4fef13cf4a4ff3842);
#
#
#             var beautify_icon_87b25296f2ef58ae1a06b489329e53da = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FFF&quot;, &quot;borderColor&quot;: &quot;gray&quot;, &quot;borderWidth&quot;: 5, &quot;iconShape&quot;: &quot;circle-dot&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: false, &quot;spin&quot;: false, &quot;textColor&quot;: &quot;#000&quot;}
#             )
#             marker_2fec424927c86120f66179d179d54ed0.setIcon(beautify_icon_87b25296f2ef58ae1a06b489329e53da);
#
#
#         var popup_ce2e63e63163c322167d7b72300530b4 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_fe7be608264f397bb92d2d0ba661558b = $(`&lt;div id=&quot;html_fe7be608264f397bb92d2d0ba661558b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p&gt;440 20 softbank&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_ce2e63e63163c322167d7b72300530b4.setContent(html_fe7be608264f397bb92d2
